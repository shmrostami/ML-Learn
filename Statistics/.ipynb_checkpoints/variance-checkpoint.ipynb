# %%
import statistics

# %% [markdown]
# ![variance.PNG](attachment:variance.PNG)

# %%
a = [30, 36, 47, 50, 52, 52, 56, 60, 63, 70, 70, 110]

# %%
statistics.variance(a)
# Out:
# 413.6363636363636

# %%
statistics.stdev(a)
# Out:
# 20.338052110179177

# %%
statistics.mean(a)
# Out:
# 58

# %%
b = (30-58)**2 + (36-58)**2 +  (47-58)**2 + (50-58)**2 + (52-58)**2 + (52-58)**2 + \
(56-58)**2 + (60-58)**2 + (63-58)**2 + (70-58)**2 + (70-58)**2 + (110-58)**2

# %%
b = b/11
b
# Out:
# 413.6363636363636
